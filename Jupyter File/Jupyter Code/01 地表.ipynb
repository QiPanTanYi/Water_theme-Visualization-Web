# %%
import pandas as pd
import json

# %%
df=pd.read_excel('../data/2013-2021年各省份地表水资源量.xlsx')
df
# Out:
#      省份 2021年地表水资源量/亿立方米  2020年地表水资源量/亿立方米  2019年地表水资源量/亿立方米  \
# 0    北京             31.6               8.2               8.6
# 1    天津             30.5               8.6               5.1
# 2    河北            227.6              55.7              51.4
# 3    山西            155.9              72.2              58.5
# 4   内蒙古            788.8             354.2             305.8
# 5    辽宁              460             357.7             211.5
# 6    吉林            380.o             504.8             437.4
# 7   黑龙江           1020.5            1221.5            1305.7
# 8    上海             45.6              49.9              40.9
# 9    江苏            442.5             486.6             163.0
# 10   浙江           1323.3            1008.8            1303.0
# 11   安徵              798            1193.7             482.1
# 12   福建            757.3             759.0            1362.5
# 13   江西           1400.6            1666.7            2032.7
# ...

# %%
data={}
for i in range(33):
    df1=list(df.iloc[i,:])
    data[df1[0]]=df1[1:]
data
# Out:
# {'北京': [31.6, 8.2, 8.6, 14.3, 12.0, 14.0, 9.3, 6.5, 9.4],
#  '天津': [30.5, 8.6, 5.1, 11.8, 8.8, 14.1, 8.7, 8.3, 10.8],
#  '河北': [227.6, 55.7, 51.4, 85.3, 60.0, 105.9, 50.9, 46.9, 76.8],
#  '山西': [155.9, 72.2, 58.5, 81.3, 87.8, 88.9, 53.8, 65.2, 81.0],
#  '内蒙古': [788.8, 354.2, 305.8, 302.4, 194.1, 268.5, 402.1, 397.6, 813.5],
#  '辽宁': [460, 357.7, 211.5, 209.3, 161.0, 286.2, 152.0, 123.7, 420.3],
#  '吉林': ['380.o', 504.8, 437.4, 422.2, 339.8, 420.7, 272.0, 251.0, 535.2],
#  '黑龙江': [1020.5, 1221.5, 1305.7, 842.2, 626.5, 720.0, 686.0, 814.4, 1253.3],
#  '上海': [45.6, 49.9, 40.9, 32.0, 27.8, 52.7, 55.3, 40.1, 22.8],
#  '江苏': [442.5, 486.6, 163.0, 274.9, 295.4, 605.8, 462.9, 296.4, 202.3],
#  '浙江': [1323.3, 1008.8, 1303.0, 848.3, 881.9, 1306.8, 1390.4, 1118.2, 917.3],
#  '安徵': [798, 1193.7, 482.1, 766.7, 717.8, 1179.2, 850.2, 712.9, 525.4],
#  '福建': [757.3, 759.0, 1362.5, 777.0, 1054.2, 2107.1, 1324.7, 1218.4, 1150.7],
#  '江西': [1400.6,
#   1666.7,
#   2032.7,
#   1129.9,
#   1637.2,
# ...

# %%
with open("../json/test2.json","w",encoding="utf-8") as f:
    f.write(json.dumps(data,ensure_ascii=False))
