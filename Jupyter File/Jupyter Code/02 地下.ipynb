# %%
import pandas as pd
import json

# %%
df=pd.read_excel("../data/2013-2021年各省份地下水资源量.xlsx")
df
# Out:
#      省份  2021年地下水资源量  2020年地下水资源量  2019年地下水资源量 2018年地下水资源量  2017年地下水资源量  \
# 0    北京         47.5         22.3         24.7        28.9         20.4
# 1    天津         11.0          5.8          4.2         7.3          5.5
# 2    河北        220.2        130.3         97.8       124.4        116.3
# 3    山西        113.7         85.9         82.5       100.3        104.1
# 4   内蒙古        238.6        243.9        233.8       253.6        207.3
# 5    辽宁        150.8        115.2        106.8        79.8         86.6
# 6    吉林        166.2        169.4        156.1       137.9        133.3
# 7   黑龙江        346.7        406.5        413.6       347.5        273.2
# 8    上海         11.2         11.6         10.4         9.6          9.2
# 9    江苏        135.3        137.8         77.5       119.7        114.5
# 10   浙江        261.8        224.4        253.7       213.9        204.3
# 11   安徵        211.7        228.6        144.8       203.7        201.0
# ...

# %%
data={}
for i in range(33):
    df1=list(df.iloc[i,:])
    data[df1[0]]=df1[1:]
data
# Out:
# {'北京': [47.5, 22.3, 24.7, 28.9, 20.4, 24.2, 20.6, 16.0, 18.7],
#  '天津': [11.0, 5.8, 4.2, 7.3, 5.5, 6.1, 4.9, 3.7, 5.0],
#  '河北': [220.2, 130.3, 97.8, 124.4, 116.3, 133.7, 113.6, 89.3, 138.8],
#  '山西': [113.7, 85.9, 82.5, 100.3, 104.1, 104.9, 86.4, 97.3, 96.9],
#  '内蒙古': [238.6, 243.9, 233.8, 253.6, 207.3, 248.2, 224.6, 236.3, 249.3],
#  '辽宁': [150.8, 115.2, 106.8, 79.8, 86.6, 120.9, 83.2, 82.3, 139.4],
#  '吉林': [166.2, 169.4, 156.1, 137.9, 133.3, 154.7, 127.4, 120.2, 160.2],
#  '黑龙江': [346.7, 406.5, 413.6, 347.5, 273.2, 285.9, 283.0, 295.4, 381.5],
#  '上海': [11.2, 11.6, 10.4, 9.6, 9.2, 11.3, 11.7, 10.0, 8.2],
#  '江苏': [135.3, 137.8, 77.5, 119.7, 114.5, 164.0, 142.4, 118.9, 97.2],
#  '浙江': [261.8, 224.4, 253.7, 213.9, 204.3, 255.5, 269.8, 231.8, 207.3],
#  '安徵': [211.7, 228.6, 144.8, 203.7, 201.0, 219.3, 193.7, 178.9, 144.5],
#  '福建': [238.7, 243.5, 339.0, 245.7, 287.5, 450.7, 332.3, 330.5, 337.6],
#  '江西': [332.0, 386.0, 482.4, 298.5, 379.5, 501.9, 465.0, 397.2, 378.4],
# ...

# %%
with open("../json/地下.json","w",encoding="utf-8") as f:
    f.write(json.dumps(data,ensure_ascii=False))
